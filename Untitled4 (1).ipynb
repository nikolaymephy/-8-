# %%
def nuclear(a, z):
  if a % 2==0 & z % 2==0:
    b=34
  elif (a % 2!=0 & z % 2==0) | (a % 2==0 & z % 2!=0):
    b=0
  else:
    b=-34
  energy=15.75*a - 17.8*a**(2/3) - 0.711*z**2/a**(1/3)-23.7*(a/2 - z)**2/a + b**(-3/4)# МэВ
  energy_ud=energy*a # МэВ
  return energy_ud
  print ("МэВ \n")
  mass_nuclear=z*1.67262192*10**(-24) + (a-z)*1.67492749804*10**(-24) #грамм
  return mass_nuclear
  print ("грамм \n")
  radius=1.3*a**(1/3)*10**(-13) #см
  return radius
  print ("см \n ")

  if a % 4==0 & z % 4==0:
    print ("Lеление данного изотопа на 2 одинаковых четно-четных осколка")
